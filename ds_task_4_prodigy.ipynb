# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/TASK_4.csv')

# %%
df.head()
# Out:
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...    Positive
# 1   Traffic was terrible this morning.           ...    Negative
# 2   Just finished an amazing workout! 💪          ...    Positive
# 3   Excited about the upcoming weekend getaway!  ...    Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#           Timestamp            User     Platform  \
# 0  15-01-2023 12:30   User123          Twitter
# 1  15-01-2023 08:45   CommuterX        Twitter
# 2  15-01-2023 15:45   FitnessFan      Instagram
# 3  15-01-2023 18:20   AdventureX       Facebook
# 4  15-01-2023 19:55   ChefCook        Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# 0   #Nature #Park                                    15     30     USA
# 1   #Traffic #Morning                                 5     10         USA
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 219 entries, 0 to 218
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Text       219 non-null    object
#  1   Sentiment  219 non-null    object
#  2   Timestamp  219 non-null    object
#  3   User       219 non-null    object
#  4   Platform   219 non-null    object
#  5   Hashtags   219 non-null    object
#  6   Retweets   219 non-null    int64
#  7   Likes      219 non-null    int64
#  8   Country    219 non-null    object
#  9   Year       219 non-null    int64
#  10  Month      219 non-null    int64
#  11  Day        219 non-null    int64
#  12  Hour       219 non-null    int64
# dtypes: int64(6), object(7)
# memory usage: 22.4+ KB

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.Retweets.head(7)
# Out:
# 0    15
# 1     5
# 2    20
# 3     8
# 4    12
# 5    25
# 6    10
# Name: Retweets, dtype: int64

# %%
type(df.Retweets)
# Out:
# pandas.core.series.Series

# %%
df.Likes.head(7)
# Out:
# 0    30
# 1    10
# 2    40
# 3    15
# 4    25
# 5    50
# 6    20
# Name: Likes, dtype: int64

# %%
type(df.Likes)
# Out:
# pandas.core.series.Series

# %%
plt.plot(df.Retweets,df.Likes,'o')
plt.show()

# %%
plt.plot(df.Likes,df.Retweets,'o')
plt.plot(df.Likes,df.Hour,'*')
plt.title("Likes vs Retweets vs Hour")
plt.show()

# %%
usa = df[df.Country == " USA"]

# %%
uk = df[df.Country == " UK "]

# %%
usa.head()
# Out:
#                                                  Text    Sentiment  \
# 10   Just published a new blog post. Check it out!...    Positive
# 18   Attending a virtual conference on AI.        ...   Neutral
# 21   Exploring the world of virtual reality.      ...    Positive
# 29   New painting in progress! 🎨                  ...    Positive
# 33   Feeling inspired after attending a workshop. ...    Positive
#
#            Timestamp               User     Platform  \
# 10  17-01-2023 15:15      BloggerX        Instagram
# 18  20-01-2023 11:30     TechConference    Facebook
# 21  21-01-2023 13:20      VRExplorer       Facebook
# 29  24-01-2023 15:00     ArtistInAction    Facebook
# 33  26-01-2023 09:45   WorkshopAttendee   Instagram
#
#                                      Hashtags  Retweets  Likes Country  Year  \
# 10   #Blogging #NewPost                              22     45     USA  2023
# 18   #AI #TechConference                             25     50     USA  2023
# ...

# %%
uk.head()
# Out:
#                                                  Text    Sentiment  \
# 4    Trying out a new recipe for dinner tonight.  ...   Neutral
# 9    Missing summer vibes and beach days.         ...   Neutral
# 25   Sunday brunch with friends.                  ...    Positive
# 27   Quiet evening with a good book.              ...    Positive
# 41   Celebrating a friend's birthday tonight! 🎂   ...    Positive
#
#            Timestamp            User     Platform  \
# 4   15-01-2023 19:55   ChefCook        Instagram
# 9   17-01-2023 12:20   BeachLover       Facebook
# 25  22-01-2023 12:00   BrunchBuddy     Instagram
# 27  23-01-2023 19:45   BookLover       Instagram
# 41  28-01-2023 19:30   BirthdayBash     Facebook
#
#                                       Hashtags  Retweets  Likes Country  Year  \
# 4    #Cooking #Food                                   12     25     UK   2023
# 9     #Summer #BeachDays                              18     35     UK   2023
# ...

# %%
plt.plot(usa.Day,usa.Hour,'o')
plt.plot(uk.Day,uk.Hour,'*')
plt.xlabel("Day")
plt.ylabel("Hour")
plt.title("Day vs Hour")
plt.show()

# %%
plt.plot(usa.Year,usa.Month,'o')
plt.plot(uk.Year,uk.Month,'*')
plt.xlabel("Year")
plt.ylabel("Month")
plt.title("Year vs Month")
plt.show()

# %%
plt.bar(usa.Retweets,usa.Likes)
plt.bar(uk.Retweets,uk.Likes)
plt.xlabel("Retweets")
plt.ylabel("Likes")
plt.title("Retweets vs Likes")
plt.show()

# %%
plt.hist(uk.Platform)
plt.hist(usa.Platform)
plt.title("Platform")
plt.show()

# %%
plt.scatter(usa.Year,usa.Year)
plt.scatter(uk.Month,uk.Day)
plt.title("Month vs Year")
plt.show()
